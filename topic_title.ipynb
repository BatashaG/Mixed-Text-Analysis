# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')  # Download the WordNet corpus

from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# Create an instance of the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jovyan/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
pip install spacy
# Out:
# Collecting spacy
#   Using cached spacy-3.6.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
# Collecting srsly<3.0.0,>=2.4.3
#   Using cached srsly-2.4.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (2.27.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy) (62.1.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from spacy) (3.1.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (1.21.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy) (4.64.0)
# Collecting smart-open<7.0.0,>=5.2.1
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Using cached spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Using cached pydantic-1.10.12-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.8-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (128 kB)
# Collecting wasabi<1.2.0,>=0.9.1
#   Using cached wasabi-1.1.2-py3-none-any.whl (27 kB)
# Collecting thinc<8.2.0,>=8.1.8
#   Using cached thinc-8.1.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (924 kB)
# Collecting typer<0.10.0,>=0.3.0
#   Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Collecting pathy>=0.10.0
#   Using cached pathy-0.10.2-py3-none-any.whl (48 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.9-py3-none-any.whl (17 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Collecting blis<0.8.0,>=0.7.8
#   Using cached blis-0.7.10-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: cymem, wasabi, typer, spacy-loggers, spacy-legacy, smart-open, pydantic, murmurhash, langcodes, catalogue, blis, srsly, preshed, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.10 catalogue-2.0.9 confection-0.1.1 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.2 preshed-3.0.8 pydantic-1.10.12 smart-open-6.3.0 spacy-3.6.0 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.7 thinc-8.1.10 typer-0.9.0 wasabi-1.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en
# Out:
# /opt/conda/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 53.3 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /opt/conda/lib/python3.9/site-packages (from en-core-web-sm==3.6.0) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (21.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.27.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.12)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (62.1.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.10)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.21.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.64.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.12)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !python -m spacy download en_core_web_sm
# Out:
# /opt/conda/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 112.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /opt/conda/lib/python3.9/site-packages (from en-core-web-sm==3.6.0) (3.6.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.27.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.10)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (21.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (62.1.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.21.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.64.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.12)
# Requirement already satisfied: pathy>=0.10.0 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.9/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2022.9.24)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

# Load the English language model
nlp = spacy.load('en_core_web_sm')
# Out:
# /opt/conda/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
df = pd.read_csv('edge_list.csv')
df.head()
# Out:
#                                                 body  \
# 0   Maybe Al Gore can drive him there in his Hummer.
# 1  The reason for that is because flood insurance...
# 2   Oh I’ve met quite a few. Depends where you live.
# 3  I’v met a couple. Similar to when convos start...
# 4  Your officials are electeded?\nUk and Scotland...
#
#                                           post_title  \
# 0  To fight climate change, ban private jets, not...
# 1  To fight climate change, ban private jets, not...
# 2  To fight climate change, ban private jets, not...
# 3  To fight climate change, ban private jets, not...
# 4  To fight climate change, ban private jets, not...
#
#                                               topics
# 0  ['climate', 'warming', 'scientists', 'scientis...
# 1  ['floods', 'flooding', 'flood', 'hurricane', '...
# 2  ['location', 'cities', 'city', 'texas', 'where...
# 3  ['climate', 'warming', 'scientists', 'scientis...
# 4  ['scotland', 'scotlands', 'scottish', 'funding...

# %%
unique_topics = df['topics'].unique()
print(unique_topics)
# Out:
# ["['climate', 'warming', 'scientists', 'scientist', 'scientific', 'earth', 'earths', 'consensus', 'weather', 'temperatures']"
#  "['floods', 'flooding', 'flood', 'hurricane', 'flooded', 'raining', 'rainfall', 'drought', 'dams', 'drainage']"
#  "['location', 'cities', 'city', 'texas', 'where', 'area', 'chicago', 'midwest', 'mn', 'central']"
#  "['scotland', 'scotlands', 'scottish', 'funding', 'taxpayer', 'westminster', 'referendum', 'minister', 'fund', 'poorer']"
#  "['bushfires', 'wildfires', 'fires', 'bushfire', 'fire', 'firefighters', 'australians', 'australias', 'drought', 'nsw']"
#  "['carbon', 'atmosphere', 'reducing', 'technology', 'energy', 'technologies', 'technological', 'emitting', 'produce', 'emit']"
#  "['happening', 'happen', 'unlikely', 'hope', 'hopefully', 'eventually', 'gonna', 'next', 'happened', 'never']"
#  "['guns', 'firearms', 'firearm', 'gun', 'shootings', 'bullet', 'weapons', 'weapon', 'gung', 'violence']"
#  "['trees', 'forests', 'tree', 'deforestation', 'forest', 'plantings', 'planting', 'planted', 'conifers', 'plants']"
#  "['insurance', 'premiums', 'premium', 'expenses', 'policies', 'costs', 'expensewise', 'income', 'pay', 'paying']"
#  "['renewables', 'renewable', 'fuels', 'coal', 'energy', 'solar', 'geothermal', 'infrastructure', 'subsidies', 'nuclear']"
#  "['solution', 'problem', 'solutions', 'problems', 'issue', 'issues', 'but', 'then', 'solve', 'solving']"
#  "['renewable', 'energy', 'demand', 'turbine', 'infrastructure', 'solar', 'green', 'pollution', 'utility', 'power']"
#  "['biomass', 'co2', 'carbon', 'firewood', 'wood', 'forests', 'coal', 'forest', 'burning', 'trees']"
#  "['solar', 'windmills', 'windmill', 'sun', 'energy', 'turbines', 'electricity', 'panels', 'fuels', 'farms']"
#  "['emissions', 'children', 'carbon', 'kids', 'population', 'child', 'overbreeding', 'climate', 'procreates', 'kid']"
#  "['adopt', 'adoption', 'children', 'childmaking', 'kids', 'childfree', 'childhoods', 'offspring', 'conceive', 'child']"
#  "['decade', 'decades', 'years', 'year', 'sooner', '90s', 'millennium', 'ten', '1999', 'old']"
#  "['hurricane', 'hurricanes', 'hurricanetropical', 'hurricanessorry', 'hurricanescyclones', 'cyclones', 'storms', 'cyclone', 'climate', 'warming']"
#  "['doomerism', 'doomism', 'doomsday', 'doomering', 'doom', 'dooms', 'doomers', 'doomer', 'doomfreaks', 'optimism']"
#  "['hopium', 'shrooms', 'psychedelic', 'pill', 'mushroom', 'drugs', 'whipit', 'smoking', 'huffing', 'gas']"
#  "['waddle', 'wagie', 'krakish', 'kraken', 'frouishia', 'shuckle', 'okjkull', 'kenoath', 'consooom', 'qwioty']"
#  "['intelligence', 'iq', 'smarter', 'smartness', 'smart', 'geniuses', 'wisdom', 'genetic', 'education', 'trait']"
#  "['article', 'articlethat', 'headline', 'headlines', 'read', 'editorialized', 'articlehello', 'reading', 'didnt', 'author']"
#  "['pollution', 'environmentally', 'polluting', 'consumers', 'environmental', 'corporations', 'consumer', 'environment', 'polluters', 'corporate']"
#  "['vegan', 'veganism', 'vegans', 'vegetarian', 'dietary', 'meat', 'dairy', 'diet', 'diets', 'foods']"
#  "['acidification', 'oceans', 'ocean', 'oceanography', 'acidity', 'acidic', 'acid', 'pollution', 'co2', 'oxygen']"
#  "['chocolate', 'burritos', 'turd', 'diarrhea', 'delicious', 'eating', 'taste', 'liver', 'cheese', 'eaten']"
#  "['predicting', 'predict', 'predictions', 'predicted', 'prediction', 'predictionshttpsuploadwikimediaorgwikipediacommonsthumb55fallpalaeotempssvg800pxallpalaeotempssvgpng', 'astroturfing', 'upcoming', 'timeless', 'accurate']"
#  "['gotcha', 'apologies', 'corrected', 'til', 'thanks', 'worries', 'noticed', 'thank', 'point', 'glad']"
#  "['smoking', 'tobacco', 'cancer', 'cigarettes', 'smoker', 'cancers', 'lung', 'smoke', 'asthma', 'health']"
#  "['refugees', 'refugee', 'europeans', 'migrants', 'europe', 'genocides', 'immegration', 'climate', 'syrian', 'migrant']"
#  "['corporations', 'corporate', 'corporation', 'shareholders', 'stakeholders', 'companies', 'government', 'company', 'executives', 'ceo']"
#  "['consumers', 'consumerism', 'consumer', 'corporations', 'stakeholders', 'consumeristic', 'customers', 'marketing', 'demand', 'corporate']"
#  "['oil', 'oils', 'exxon', 'exxonmobil', 'fuel', 'bezos', 'crude', 'gas', 'barrels', 'refined']"
#  "['china', 'chinas', 'emissions', 'pollution', 'countries', 'india', 'co2', 'nations', 'usa', 'climate']"
#  "['capita', 'population', 'populace', 'per', 'proportion', 'countries', 'inhabitants', 'richest', 'statistic', 'indias']"
#  "['agriculture', 'livestock', 'agricultural', 'farms', 'crops', 'cows', 'grazing', 'cattle', 'farming', 'farmers']"
#  "['overpopulation', 'overpopulated', 'populations', 'population', 'malthus', 'growth', 'sustainable', 'famine', 'mortality', 'economies']"
#  "['mirror', 'glances', 'look', 'eye', 'black', 'shade', 'blind', 'looks', 'something', 'face']"
#  "['coal', 'renewables', 'fuels', 'coalfired', 'renewablesgreentech', 'powerplants', 'carboniferous', 'electricity', 'powerenergy', 'energy']"
#  "['olds', 'aged', 'older', 'old', 'age', 'young', 'politicans', 'politicians', 'generations', 'politics']"
#  "['yep', 'yeah', 'yes', 'nah', 'nope', 'absolutely', 'indeed', 'no', 'uh', 'so']"
#  "['blaming', 'blame', 'arsonists', 'pollution', 'arson', 'fuels', 'gasoline', 'suing', 'manufacturers', 'oilfuel']"
#  "['communism', 'communist', 'commies', 'capitalism', 'socialism', 'socialist', 'commie', 'capitalists', 'leninism', 'stalinism']"
#  "['america', 'americans', 'europeans', 'nationalism', 'american', 'citizenship', 'nato', 'nations', 'worlddeveloping', 'countrys']"
#  "['greenhouse', 'co2', 'climate', 'warming', 'atmospheric', 'carbon', 'atmosphere', 'extinction', 'sun', 'methane']"
#  "['facts', 'fact', 'factual', 'factually', 'truth', 'sources', 'evidence', 'contradicting', 'assertions', 'anecdotal']"
#  "['meat', 'meats', 'beef', 'meals', 'eat', 'steaks', 'diet', 'eating', 'poultry', 'chicken']"
#  "['straws', 'straw', 'soda', 'plastic', 'drinks', 'drinkingstrawbased', 'liquids', 'lid', 'ban', 'starbucks']"
#  "['transportation', 'buses', 'commute', 'highways', 'bus', 'roads', 'traffic', 'freeway', 'transport', 'infrastructure']"
#  "['flying', 'flights', 'airplanes', 'flight', 'airlines', 'travel', 'airline', 'pilots', 'fly', 'planes']"
#  "['percentage', 'percent', 'majority', 'top', 'ranks', 'bottom', 'average', 'middle', 'low', 'lower']"
#  "['nuclear', 'reactors', 'reactor', 'chernobyl', 'fukushima', 'nukes', 'plutonium', 'fission', 'uranium', 'radioactive']"
#  "['contraceptives', 'abortions', 'abortion', 'parenthood', 'birthcontrol', 'sterilization', 'malthus', 'births', 'reproduce', 'pregnancy']"
#  "['ozone', 'aerosol', 'kyoto', 'fluorocarbons', 'chemicals', 'cfcs', 'fixedhttpswwwweforumorgagenda201709ozoneactionworkedenvironmentalprogress', 'nuclear', 'o3', 'refrigerants']"
#  "['replying', 'respond', 'reply', 'responded', 'replied', 'response', 'pedant', 'comment', 'misguided', 'fair']"
#  "['history', 'recorded', 'learn', 'forgets', 'edgy', 'studied', 'boggling', 'books', 'understood', 'read']"
#  "['ships', 'freighters', 'maritime', 'tankers', 'cruise', 'boats', 'cruises', 'yachts', 'ship', 'boat']"
#  "['plague', 'smallpox', 'pandemic', 'pandemics', 'fever', 'vaccination', 'vaccines', 'vaccine', 'disease', 'vaccinating']"
#  "['voter', 'voting', 'vote', 'voters', 'ballot', 'votes', 'election', 'elections', 'voted', 'elected']"
#  "['conservatism', 'conservative', 'conservatives', 'liberal', 'liberals', 'bipartisanship', 'progressive', 'elderly', 'romney', 'voterbase']"
#  "['emissions', 'emission', 'carbon', 'anthropogenic', 'fewer', 'reduce', 'sustaining', 'reduced', 'implying', 'improving']"
#  "['extinction', 'extinctions', 'extinct', 'biodiversity', 'species', 'mankind', 'nature', 'humanity', 'destroying', 'collapse']"
#  "['polls', 'polling', 'polled', 'pollsbut', 'surveys', 'surveyed', 'statistics', 'poller', 'statistic', 'sample']"
#  "['clothing', 'fashion', 'wardrobe', 'retail', 'clothes', 'boutique', 'shop', 'goodwill', 'retailers', 'thrift']"
#  "['mentally', 'mental', 'stupidity', 'insanity', 'psychosis', 'schizophrenia', 'psychiatry', 'ignorance', 'illness', 'therapy']"
#  "['thanks', 'welcome', 'thank', 'cheers', 'glad', 'beautiful', 'congrats', 'amazing', 'link', 'appreciate']"
#  "['ai', 'intelligent', 'regulatory', 'utility', 'sentient', 'humanity', 'licensing', 'blindly', 'harm', 'protecting']"
#  "['chatbots', 'chatbot', 'bot', 'conversation', 'bots', 'chat', 'ai', 'conversations', 'chatgpt', 'ais']"
#  "['dead', 'dying', 'dies', 'death', 'die', 'deaths', 'alive', 'undead', 'hell', 'life']"
#  "['programming', 'programmer', 'coding', 'abstractions', 'abstraction', 'developers', 'computerized', 'programmable', 'languages', 'frameworks']"
#  "['video', 'vid', 'remarkable', 'link', 'really', 'intentional', 'watch', 'explains', 'debunking', 'thank']"
#  "['fascism', 'fascist', 'fascists', 'mussolini', 'authoritarianism', 'dictatorial', 'authoritarian', 'nazis', 'socialist', 'nazi']"
#  "['suffering', 'helplessness', 'life', 'afterlife', 'lifes', 'religion', 'live', 'suffer', 'hypocritical', 'death']"
#  "['lol', 'hahaha', 'haha', 'lmao', 'hahahaha', 'hahahahaha', 'funny', 'wtf', 'kidding', 'arent']"
#  "['chatbot', 'chatbots', 'bot', 'suicidal', 'suicide', 'conversation', 'chatgpt', 'chat', 'conversing', 'harm']"
#  "['suicidal', 'suicide', 'sucide', 'depression', 'psychopath', 'fatalistic', 'depressed', 'mentally', 'mental', 'therapy']"
#  "['dishonesty', 'lying', 'lie', 'lies', 'arrogance', 'misinformation', 'recklessness', 'honest', 'telling', 'teller']"
#  "['children', 'kids', 'climate', 'generation', 'doomsday', 'grandchildren', 'parents', 'scientists', 'hypothetical', 'parentshttpswwwscientificamericancomarticlechildrenchangetheirparentsmindsaboutclimatechange']"
#  "['59', 'younger', '35', 'age', '38', 'old', '34', '30', '44', '46']"
#  "['church', 'churchs', 'churches', 'catholic', 'worship', 'worshipers', 'priests', 'religions', 'christianity', 'sect']"
#  "['changing', 'changes', 'change', 'actions', 'affect', 'policy', 'action', 'systemic', 'individual', 'governments']"
#  "['geoengineering', 'geoengenering', 'geoenginneering', 'ithttpsgeoengineeringenvironmentharvardedugeoengineering', 'geophysically', 'geo', 'engineering', 'drilling', 'solar', 'strategic']"
#  "['enviromentalism', 'environmentalism', 'environmentalist', 'environmental', 'climate', 'enviromental', 'environment', 'initiatives', 'responsibility', 'government']"
#  "['education', 'students', 'curriculum', 'teach', 'abolish', 'funding', 'forcing', 'public', 'learn', 'syllabus']"
#  "['lobbying', 'lobbyists', 'lobbys', 'bribery', 'politicians', 'lobby', 'corporations', 'corruption', 'politics', 'capitalism']"
#  "['capitalism', 'capitalist', 'capitalists', 'socialism', 'economic', 'economies', 'economy', 'socialist', 'consumerism', 'poverty']"
#  "['scientists', 'scientific', 'sciences', 'scientist', 'science', 'nature', 'research', 'findings', 'evidence', 'theory']"
#  "['sub', 'subs', 'subreddit', 'subreddits', 'reddit', 'subscribers', 'mods', 'unsub', 'belongs', 'post']"
#  "['plants', 'co2', 'greenhouse', 'fertilizer', 'grow', 'ferns', 'trees', 'growing', 'growth', 'algae']"
#  "['fox', 'news', 'cnn', 'primetime', 'propaganda', 'biased', 'bias', 'media', 'liberalconservative', 'liberal']"
#  "['blaming', 'blamed', 'blame', 'fault', 'responsibility', 'responsible', 'victim', 'guilt', 'others', 'guilty']"
#  "['starving', 'starvation', 'hunger', 'poverty', 'starve', 'feeding', 'food', 'economics', 'feed', 'luxury']"
#  "['environmental', 'fuelefficient', 'climate', 'consumers', 'conservationism', 'environment', 'consumer', 'markets', 'powerplants', 'externality']"
#  "['recycling', 'recycled', 'recycle', 'recyclables', 'recyclable', 'landfill', 'landfills', 'waste', 'environmentally', 'plastics']"
#  "['children', 'kids', 'childrens', 'parents', 'child', 'kids1', 'teach', 'parent', 'ageappropriate', 'poverty']"
#  "['boomers', 'boomer', 'millennials', 'generations', 'millennial', 'generation', 'millenials', 'boomerinchief', 'millenialsgenxboomers', 'generational']"
#  "['idiot', 'stupid', 'dumber', 'dumb', 'idiotwe', 'lmao', 'troll', 'are', 'clearly', 'lol']"
#  "['selfishness', 'selfish', 'selfishly', 'oneself', 'motivations', 'cynical', 'themselves', 'yourself', 'selfinterested', 'willingly']"
#  "['agriculture', 'crops', 'agricultural', 'climate', 'farming', 'soils', 'greenhouses', 'livestock', 'warming', 'crop']"
#  "['democracy', 'democracies', 'democratic', 'electoral', 'electorate', 'republic', 'tyranny', 'elect', 'ballot', 'nationalism']"
#  "['insults', 'arguing', 'insulting', 'conversation', 'rebuttal', 'troll', 'ignorant', 'debate', 'argue', 'refute']"
#  "['volunteer', 'outreach', 'climate', 'activist', 'lobbying', 'advocate', 'citizens', 'volunteershttpscitizensclimatelobbyorgjoinweeklyintrocall', 'policy', 'lobby']"
#  "['leaders', 'leader', 'leadership', 'government', 'rulers', 'genocide', 'revolt', 'freedom', 'ensuring', 'control']"
#  "['billionaires', 'profits', 'economic', 'rich', 'billions', 'starving', 'starvation', 'consume', 'reducing', 'money']"
#  "['coffee', 'cups', 'styrofoam', 'starbucks', 'cup', 'coffe', 'mug', 'demand', 'lattes', 'consumers']"
#  "['ev', 'evs', 'tesla', 'electricity', 'cars', 'electric', 'car', 'vehicles', 'cost', 'toyota']"
#  "['emissions', 'corporations', 'renewable', 'emissionsbut', 'corporate', 'climate', 'fuels', 'consumer', 'exxonmobile', 'companies']"
#  "['californias', 'californians', 'californian', 'california', 'san', 'cali', 'population', 'ca', 'housing', 'states']"
#  "['sacrifices', 'sacrifice', 'moral', 'donating', 'survive', 'willingness', 'push', 'salvation', 'shove', 'achieving']"
#  "['stones', 'drown', 'coal', 'die', 'sticks', 'phones', 'cruel', 'wall', 'heads', 'burn']"
#  "['co2', 'emissions', 'carbon', 'coal', 'gasoline', 'fueleconomy', 'costs', 'reactors', 'trashing', 'capping']"
#  "['tax', 'carbon', 'taxes', 'emissions', 'taxed', 'polluting', 'pollution', 'revenue', 'corporations', 'economy']"
#  "['payment', 'payments', 'pay', 'afford', 'wage', 'owed', 'payoff', 'earn', 'free', 'paid']"
#  "['studies', 'researcher', 'citations', 'anecdotal', 'scientific', 'cite', 'evidence', 'httpiopscienceioporgarticle10108817489326aa822a', 'publication', 'journals']"
#  "['leftist', 'leftists', 'democrats', 'leftwing', 'conservatism', 'liberal', 'dems', 'lefts', 'lefty', 'lefties']"
#  "['sources', 'evidence', 'claims', 'source', 'cited', 'claim', 'claiming', 'researched', 'cite', 'citation']"
#  "['shill', 'shills', 'shillhole', 'shillbot', 'shilling', 'lobbyists', 'misinformation', 'propaganda', 'redditors', 'misleading']"
#  "['libertarians', 'libertarian', 'primaries', 'democrats', 'voting', 'parties', 'elections', 'libertarianism', 'vote', 'independents']"
#  "['protests', 'protesting', 'protest', 'protestings', 'protesters', 'activism', 'protestsriots', 'marches', 'riot', 'violent']"
#  "['agree', 'agreed', 'disagree', 'exactly', 'totally', 'true', 'definitely', 'really', 'absolutely', 'right']"
#  "['canada', 'lakes', 'anywhere', 'places', 'south', 'usa', 'russia', 'southern', 'china', 'northern']"
#  "['snowfall', 'snow', 'winters', 'snows', 'snowed', 'snowy', 'weather', 'winter', 'storms', 'spring']"
#  "['fuels', 'petroleum', 'coal', 'shale', 'fracking', 'gasoline', 'fuel', 'oil', 'fossil', 'subsidies']"
#  "['gasoline', 'fuel', 'gas', 'rural', 'transportation', 'oil', 'econ', 'gallon', 'demographics', 'transport']"
#  "['suicide', 'harm', 'ai', 'intentionality', 'harmed', 'ais', 'mentally', 'mental', 'casualty', 'thoughtlessly']"
#  "['suburbs', 'rural', 'housing', 'neighborhood', 'apartments', 'renting', 'rents', 'apartment', 'rent', 'cities']"
#  "['immigration', 'immigrants', 'immigrant', 'borders', 'nationalist', 'increasingly', 'border', 'gdp', 'politics', 'labour']"
#  "['tornadoes', 'tornado', 'tornados', 'storms', 'thunderstorms', 'weather', 'extremes', 'severity', 'summer', 'winter']"
#  "['ac', 'acs', 'airconditioning', 'cooling', 'aircon', 'insulated', 'electricity', 'insulation', 'compressor', 'airflow']"
#  "['canadas', 'canada', 'canadians', 'canadian', 'manitoba', 'saskatchewan', 'trudeau', 'calgary', 'provinces', 'harper']"
#  "['scooters', 'scooter', 'motorcycles', 'ebikes', 'walkingbiking', 'bikes', 'cyclists', 'riding', 'cyclist', 'electric']"
#  "['bikes', 'bike', 'bikepacking', 'biking', 'bicycle', 'cycling', 'biked', 'riding', 'scooter', 'commuting']"
#  "['venus', 'venusian', 'greenhouse', 'planets', 'planet', 'co2', 'warming', 'mars', 'sunlight', 'atmosphere']"
#  "['fireflies', 'firefly', 'butterflies', 'bugs', 'butterfly', 'summer', 'lightning', 'outside', 'kids', 'habitat']"
#  "['reading', 'grades', 'grade', 'gradeish', 'reads', 'literate', 'writing', 'comprehension', 'read', 'communicate']"
#  "['war', 'wars', 'insurgency', 'armies', 'battle', 'iraq', 'taliban', 'fighting', 'military', 'wwiii']"
#  "['driving', 'vehicles', 'autonomous', 'drivers', 'cars', 'driver', 'vehicle', 'driven', 'car', 'self']"
#  "['movie', 'film', 'plot', 'interstellar', 'starring', 'armageddon', 'oscar', 'fireflies', 'joaquin', 'anime']"
#  "['emissions', 'economic', 'climate', 'economies', 'industrialized', 'nations', 'decolonization', 'poverty', 'wealth', 'countries']"
#  "['wall', 'walls', 'walled', 'borders', 'walle', 'fortifications', 'fences', 'border', 'seawall', 'fence']"
#  "['jobs', 'unemployed', 'employers', 'workers', 'unemployment', 'wages', 'factories', 'job', 'workweek', 'productivity']"
#  "['homeschool', 'homeschooling', 'homeschooled', 'school', 'schools', 'classrooms', 'highschool', 'students', 'education', 'kids']"
#  "['violence', 'violent', 'justified', 'peaceful', 'brutality', 'advocating', 'vigilante', 'vigilantism', 'crimes', 'arresting']"
#  "['knowledge', 'information', 'concept', 'expertise', 'intelligence', 'experts', 'theories', 'understanding', 'education', 'intuitive']"
#  "['wealthy', 'rich', 'wealth', 'poverty', 'poorer', 'income', 'richer', 'poor', 'earners', 'millionaires']"
#  "['generations', 'generation', 'future', 'technology', 'lifetime', 'neoliberal', 'older', 'paradigm', 'environment', 'world']"
#  "['gifgiphya9syz3fmtvjlg', 'gifgiphygc0j2f2ztrazngqpnp', 'httpsyoutubeqc4nsnbmgslistplksyvgwmyz9w6ly2y2rtilgaup0oi2gzlt246httpsyoutubeqc4nsnbmgslistplksyvgwmyz9w6ly2y2rtilgaup0oi2gzlt246', 'you', 'shush', 'with', 'elmo', 'come', 'khttpsmediagiphycommediafml0fgaxvx1emgiphygif', 'shouldhttpsiimgurcomgt0ereejpg']"
#  "['millennials', 'millennial', 'generations', 'generation', 'computers', 'technology', 'computer', 'tech', 'computing', 'hardware']"
#  "['disgusting', 'horrifying', 'nasty', 'horrific', 'terrifying', 'worse', 'scary', 'terrified', 'jesus', 'scarier']"
#  "['mosquitoesbees', 'wasps', 'insects', 'mosquitoes', 'bees', 'mosquitos', 'bugs', 'mosquito', 'flies', 'spiders']"
#  "['cars', 'porsche', 'car', 'chrysler', 'vehicle', 'toyota', 'oldsmobile', 'subaru', 'repairs', 'corolla']"
#  "['renewables', 'environmentalists', 'france', 'electricity', 'energy', 'greenpeace', 'carbon', 'reactors', 'nuclear', 'frances']"
#  "['smartphones', 'phones', 'cellphone', 'iphones', 'iphone', 'phone', 'apple', 'samsung', 'ios', 'telecommunications']"
#  "['advertisements', 'advertisement', 'advertising', 'ads', 'propaganda', 'marketing', 'ad', 'exploitative', 'campaign', 'livelihood']"
#  "['tax', 'taxes', 'taxed', 'revenue', 'economics', 'httpssaylordotorggithubiotextintroductiontoeconomicanalysiss0601effectsoftaxeshtml', 'economic', 'commodity', 'corporations', 'consumers']"
#  "['denialism', 'denial', 'hoax', 'believe', 'happening', 'reality', 'fact', 'evidence', 'decades', 'doubt']"
#  "['ticks', 'tick', 'tickborne', 'pests', 'fleatick', 'critters', 'rabies', 'squirrels', 'rodents', 'pigeons']"
#  "['insecticides', 'insecticide', 'pesticides', 'pesticide', 'insects', 'insect', 'lepidopterans', 'moths', 'herbicides', 'climate']"
#  "['earth', 'flat', 'copernicus', 'theories', 'earthers', 'corroboration', 'earther', 'creationism', 'consensus', 'proven']"
#  "['methane', 'co2', 'biogas', 'gases', 'gas', 'fuel', 'greenhouse', 'pollution', 'pollutant', 'atmosphere']"
#  "['mysteries', 'mystery', 'storytelling', 'lost', 'hbo', 'reveal', 'twilight', 'ending', 'writers', 'episodes']"
#  "['keynesians', 'keynesian', 'economists', 'keynes', 'economics', 'economist', 'economys', 'economy', 'criticisms', 'burocrats']"
#  "['tractors', 'tractor', 'farmers', 'farmer', 'mower', 'deere', 'repairs', 'mechanic', 'deerehttpswwwwiredcomstoryjohndeerefarmersrighttorepair', 'manufacturers']"
#  "['bugs', 'windshield', 'stinkbugs', 'insect', 'cars', 'bug', 'car', 'wipe', 'driving', 'cars13']"
#  "['nasa', 'nasas', 'spaceflight', 'funding', 'budget', 'spacecraft', 'budgeted', 'shuttle', 'missions', 'funded']"
#  "['welfare', 'socialism', 'conservative', 'entitlement', 'scapegoating', 'crisis', 'discourse', 'bill', 'economyand', 'unwilling']"
#  "['uber', 'ubers', 'taxis', 'uberlyft', 'lyft', 'taxi', 'cab', 'cabs', 'vehicles', 'driving']"
#  "['data', 'dataset', 'anecdata', 'information', 'kindda', 'figures', 'mediawith', 'stuff', 'not', 'compression']"
#  "['worse', 'awful', 'terrible', 'bad', 'comparison', 'different', 'way', 'far', 'really', 'than']"
#  "['her', 'herself', 'she', 'shes', 'greta', 'with', 'girl', 'child', 'parents', 'to']"
#  "['sweating', 'sweat', 'warmer', 'temperature', 'hypothermia', 'temperatures', 'temp', 'hyperthermia', 'cooling', 'heat']"
#  "['lawn', 'lawns', 'grass', 'lawnnatural', 'mowing', 'weeds', 'yard', 'planting', 'herbicides', 'invasive']"
#  "['idiocracy', 'eugenics', 'stupidity', 'genetic', 'intelligent', 'idiocracyesque', 'nurture', 'generation', 'smarter', 'idiots']"
#  "['economy', 'economists', 'economic', 'catastrophic', 'prosperous', 'collapse', 'decades', 'growth', 'environment', 'societal']"
#  "['pakistan', 'pakistans', 'pakistanis', 'pakistani', 'punjab', 'kashmir', 'afghanistan', 'taliban', 'bangladesh', 'afghan']"
#  "['implied', 'agreeing', 'wooosh', 'point', 'reiterating', 'entirely', 'statement', 'worded', 'figured', 'seriousness']"
#  "['reparations', 'reparationsll', 'reparation', 'aid', 'pay', 'fund', 'nations', 'countries', 'relentessly', 'compensate']"
#  "['fantasy', 'fantasies', 'realistic', 'reality', 'planning', 'real', 'plan', 'proposals', 'world', 'ideas']"
#  "['underrated', 'comment', 'comments', 'best', 'should', 'above', 'obvious', 'too', 'bring', 'top']"
#  "['icbms', 'pentagon', 'binnenhof', '51', 'raiding', 'nearby', 'busy', '6am', 'february', 'area']"
#  "['climate', 'wealthy', 'partisan', 'populace', 'rich', 'cynical', 'inequality', 'lifestyles', 'poorworking', 'poor']"
#  "['ukraine', 'ukrainians', 'ukraines', 'ukrainian', 'kyiv', 'corruption', 'russia', 'bulgarians', 'corrupt', 'russians']"
#  "['governments', 'politicians', 'government', 'corruption', 'politician', 'democracies', 'corrupt', 'bureaucracy', 'dictatorships', 'bribery']"
#  "['anger', 'angry', 'mad', 'upset', 'madness', 'emotion', 'hating', 'brain', 'disbelief', 'obstinate']"
#  "['conspiracies', 'conspiracy', 'paranoia', 'scandal', 'fabricated', 'mysteries', 'evidence', 'accusing', 'faking', 'paranormal']"
#  "['thats', 'yous', 'meant', 'lol', 'totally', 'or', 'point', 'obvious', 'sorry', 'were']"
#  "['obese', 'obesity', 'diet', 'fat', 'nutritional', 'malnourished', 'eat', 'healthier', 'eating', 'calorie']"
#  "['mars', 'terraform', 'earth', 'asteroid', 'civilization', 'space', 'colonizing', 'war', 'apocalypse', 'colonised']"
#  "['wealthiest', 'richest', 'wealthy', 'consumption', 'affluent', 'rich', 'energy', 'poorest', 'tenth', 'earners']"
#  "['slavery', 'slaves', 'slave', 'slavesex', 'enslavement', 'punishments', 'servants', 'trafficking', 'indentured', 'servant']"
#  "['charities', 'donations', 'donating', 'donation', 'donate', 'donors', 'donated', 'shelters', 'homeless', 'ngos']"
#  "['robots', 'robot', 'asimov', 'asimovs', 'robotics', 'laws', 'ai', 'law', 'ethical', 'humanity']"
#  "['charging', 'charge', 'charger', 'charges', 'ev', 'tesla', 'parking', 'outlet', 'chargers', 'outlets']"
#  "['quote', 'slogan', 'tyrion', 'lannister', 'shatner', 'king', 'narrator', 'hypothetical', 'douglas', 'ethnostate']"
#  "['hydrogen', 'fuel', 'gasoline', 'gas', 'energy', 'hydro', 'oxygen', 'water', 'electricity', 'hydrides']"
#  "['archeological', 'archaeological', 'archaeology', 'neolithic', 'paleolithic', 'prehistory', 'ancient', 'archeologists', 'geological', 'geology']"
#  "['budget', 'spending', 'spendings', 'military', 'dod', 'funding', 'mil', 'spends', 'servicemen', 'weaponry']"
#  "['taxes', 'tax', 'taxation', 'irs', 'taxed', 'income', 'federal', 'spending', 'wealthy', 'rich']"
#  "['racist', 'supremacists', 'racism', 'antiracism', 'supremacist', 'racists', 'antiracist', 'racial', 'blacks', 'whites']"
#  "['currency', 'monetary', 'debt', 'fiat', 'subjectcurrency', 'banking', 'debtsdebts', 'dollars', 'payments', 'coins']"
#  "['three', 'tripled', 'two', 'one', 'many', 'ring', 'damn', 'enough', 'more', 'wheels']"
#  "['mp3s', 'mp3', 'music', 'cassettes', 'audiophile', 'cassette', 'tapes', 'audio', 'vinyl', 'spotify']"
#  "['bulbs', 'incandescents', 'incandescent', 'bulb', 'candlelight', 'lighting', 'lights', 'fluorescents', 'fluorescent', '100w']"
#  "['deaths', 'growth', 'data', 'disasters', 'hospitalizations', 'statistical', 'chart', 'metrics', 'conjecture', 'timeframe']"
#  "['healthcare', 'health', 'insurance', 'medical', 'hospitals', 'patients', 'universal', 'hospital', 'americans', 'doctors']"
#  "['office', 'telecommuting', 'workspace', 'workweek', 'employees', 'shifts', 'commute', 'roommates', 'employee', 'employer']"
#  "['netherlands', 'amsterdam', 'amsterdams', 'rotterdam', 'dutch', 'belgium', 'groningen', 'dutchies', 'eindhoven', 'noordholland']"
#  "['ideas', 'interested', 'suggestion', 'things', 'idea', 'practical', 'suggest', 'something', 'consider', 'thing']"
#  "['socialism', 'socialist', 'socialists', 'capitalist', 'communist', 'capitalism', 'communism', 'welfare', 'soviet', 'democratic']"
#  "['greens', 'green', 'greeninfluenced', 'taxpayers', 'leftist', 'recycler', 'politics', 'planet', 'reliant', 'society']"
#  "['lasers', 'laser', 'laserbased', 'photons', 'beam', 'missiles', 'missile', 'light', 'transmitting', 'transmit']"
#  "['energy', 'solar', 'electricity', 'exothermic', 'heat', 'hydropower', 'thermal', 'photovoltaic', 'thermodynamics', 'albedo']"
#  "['appliances', 'cookware', 'stainless', 'cheap', 'cheaply', 'kitchen', 'pots', 'microwave', 'fridge', 'pans']"
#  "['livestock', 'farms', 'meat', 'agriculture', 'beef', 'emissions', 'consumption', 'farming', 'dairy', 'foodsciencebabe']"
#  "['clinton', 'clintons', 'hillary', 'dnc', 'dems', 'trump', 'corruption', 'dissidents', 'candidates', 'republicans']"
#  "['plants', 'organisms', 'biology', 'herbivores', 'beings', 'plant', 'organism', 'jainism', 'science', 'cells']"
#  "['jaded', 'narcissistic', 'cynical', 'mindset', 'attitudes', 'objective', 'infuriating', 'frustrated', 'miserable', 'perspective']"
#  "['ai', 'ais', 'intelligence', 'intelligent', 'artificial', 'cognitive', 'brain', 'concept', 'machine', 'computers']"
#  "['chatbots', 'chatbot', 'eliza', 'cleverbot', 'bot', 'chatgpt', 'ai', 'messenger', 'bots', 'chatted']"
#  "['ai', 'fatalities', 'cognitive', 'agents', 'suicide', 'neural', 'programmed', 'murderer', 'deaths', 'aiassisted']"
#  "['eliza', 'elizahttpsenmwikipediaorgwikieliza', 'ai', 'barbie', 'old', 'idiot', 'older', 'article', 'antique', 'moron']"
#  "['fucked', 'humanity', 'fuck', 'globally', 'doomed', 'consequences', 'worry', 'we', 'irreversibly', 'utterly']"
#  "['nature', 'natures', 'humanity', 'individuality', 'inherently', 'trait', 'human', 'narcissism', 'nurture', 'innate']"
#  "['linguistic', 'language', 'neural', 'turing', 'neuron', 'brains', 'neurons', 'models', 'learns', 'neuro']"
#  "['chatgpt', 'chatbot', 'chat', 'gpt4', 'gpt', 'gptj', 'gpt35', 'conversations', 'slang', 'text']"
#  "['chatbots', 'ai', 'chatbot', 'ais', 'causally', 'mental', 'bot', 'culpability', 'causal', 'moral']"
#  "['ai', 'orphans', 'raised', 'parental', 'parent', 'generational', 'miniseries', 'actress', 'literary', 'mirandas']"
#  "['guardrails', 'guardrail', 'safety', 'buildings', 'protect', 'stairwell', 'danger', 'rails', 'accidents', 'restrictions']"
#  "['frogs', 'frog', 'boiling', 'cats', 'water', 'cat', 'boiled', 'experiment', 'bird', 'heat']"
#  "['strike', 'strikes', 'striking', 'protest', 'employees', 'stunt', 'publicity', 'employer', 'action', 'supposed']"
#  "['death', 'dead', 'dying', 'gunshot', 'alive', 'analogy', 'imminent', 'carbon', 'scifi', 'reverse']"
#  "['older', 'younger', 'old', 'age', 'youngster', 'young', '25', 'yutz', 'kid', '30']"
#  "['duck', 'ducks', 'beak', 'quacks', 'carrot', 'grocery', 'quackers', 'containers', 'lettuce', 'seagulls']"
#  "['invention', 'technological', 'technologies', 'worldchanging', 'internet', 'phones', 'computers', 'tech', 'breakthroughs', 'iphone']"
#  "['hypocrite', 'hypocrisy', 'hypocrites', 'hypocritical', 'hypocrit', 'tolerant', 'intolerant', 'tolerance', 'sin', 'judging']"
#  "['voters', 'voting', 'vote', 'youth', 'ballot', 'youths', 'election', 'votes', 'young', 'younger']"
#  "['oceans', 'plastics', 'microplastic', 'ocean', 'sea', 'plankton', 'proenvironmental', 'marine', 'sand', 'plastic']"
#  "['sheep', 'sheeple', 'herders', 'troll', 'insult', 'argue', 'analogy', 'empathy', 'you', 'pathetic']"
#  "['automobiles', 'electric', 'cars', 'automotive', 'vehicles', 'car', 'inverter', 'electronic', 'consumption', 'driving']"
#  "['growth', 'productivity', 'economic', 'gdp', 'macroeconomics', 'economy', 'innovation', 'advancements', 'economists', 'economics']"
#  "['revolution', 'revolutions', 'revolutionaries', 'revolutionary', 'revolt', 'disenfranchised', 'democracy', 'liberty', 'authoritarian', 'powerless']"
#  "['strawman', 'strawmanbombing', 'strawmen', 'straw', 'whataboutism', 'whataboutist', 'nonsense', 'environmentalists', 'tinfoil', 'argument']"
#  "['blockchains', 'blockchain', 'emissions', 'decentralized', 'governments', 'auditing', 'carbon', 'decentralised', 'databases', 'government']"
#  "['protesting', 'protests', 'protest', 'kids', 'politicians', 'millennial', 'crowdfunding', 'petition', 'kid', 'scientists']"
#  "['socialist', 'socialism', 'socialists', 'nazis', 'nazi', 'marxism', 'fascist', 'hitler', '1930s', 'privatization']"
#  "['legislation', 'legislature', 'legalizes', 'government', 'feinstein', 'educate', 'proposed', 'initiative', 'senate', 'boycotts']"
#  "['tax', 'taxes', 'taxy', 'revenue', 'carbon', 'income', 'incentivizing', 'paying', 'revenueneutral', 'less']"
#  "['tesla', 'teslas', 'porsche', 'bmw', 'corvette', 'car', 'camaro', 'toyota', 'mustang', 'ev']"
#  "['guillotines', 'guillotine', 'socialjusticeinclined', 'revolution', 'detriment', 'pandering', 'politicial', 'murderer', 'radical', 'capitalist']"
#  "['truck', 'trucks', 'towing', 'hauling', 'vehicle', 'tow', 'haul', 'pickup', 'minivan', 'trucksuvvan']"
#  "['greta', 'gretaration', 'zoomie', 'generation', 'zoomer', 'speak', 'born', 'zoomers', 'gen', 'abeg']"
#  "['alarmism', 'alarmist', 'alarms', 'alarm', 'alarmed', 'security', 'radar', 'police', 'fears', 'lobbyinghttpsnpredditcomrworldnewscommentsbxgd5psinglemostimportantstatontheplanetalarmaseq6bvl0']"
#  "['recycling', 'glass', 'recyclein', 'recycled', 'recyclable', 'bottles', 'bottled', 'bottle', 'reuse', 'contamination']"
#  "['contractor', 'contractors', 'employment', 'employer', 'freelancing', 'contract', 'freelancers', 'freelancer', 'employers', 'employee']"
#  "['obamacare', 'recession', 'deficits', 'obama', 'debt', 'economy', 'obamas', 'bill', 'mandate', 'reform']"
#  "['fireball', 'fireballs', 'fires', 'fire', 'flamethrower', 'gun', 'throw', 'cheering', 'really', 'never']"
#  "['ev', 'winter', 'evs', 'snow', 'commute', 'freezing', 'cold', 'climates', 'electric', 'warm']"
#  "['loans', 'loan', 'debt', 'finance', 'car', 'afford', 'vehicle', 'paying', 'payment', 'interest']"]

# %%
import ast

# Convert the string representation of the list to a list
df['topics'] = df['topics'].apply(ast.literal_eval)

# %%
# Function to extract the most repeated word from a list of words
def get_most_repeated_word(words):
    lemmatized_words = [token.lemma_ for token in nlp(' '.join(words))]
    word_counts = Counter(lemmatized_words)
    most_common_word, count = word_counts.most_common(1)[0]
    return most_common_word if count > 1 else lemmatized_words[0]

# %%
import pandas as pd
from collections import Counter
from collections import defaultdict
from collections import defaultdict, Counter
# Out:
#                                                 body  \
# 0   Maybe Al Gore can drive him there in his Hummer.
# 1  The reason for that is because flood insurance...
# 2   Oh I’ve met quite a few. Depends where you live.
# 3  I’v met a couple. Similar to when convos start...
# 4  Your officials are electeded?\nUk and Scotland...
#
#                                           post_title  \
# 0  To fight climate change, ban private jets, not...
# 1  To fight climate change, ban private jets, not...
# 2  To fight climate change, ban private jets, not...
# 3  To fight climate change, ban private jets, not...
# 4  To fight climate change, ban private jets, not...
#
#                                               topics repeated_word
# 0  [climate, warming, scientists, scientist, scie...     scientist
# 1  [floods, flooding, flood, hurricane, flooded, ...         flood
# 2  [location, cities, city, texas, where, area, c...      location
# 3  [climate, warming, scientists, scientist, scie...     scientist
# 4  [scotland, scotlands, scottish, funding, taxpa...      scotland

# %%
# Define the updated get_most_repeated_word() function
def get_most_repeated_word(words, assigned_words):
    lemmatized_words = [token.lemma_ for token in nlp(' '.join(words))]
    word_counts = Counter(lemmatized_words)

    for word, count in word_counts.most_common():
        if count > 1:
            root_word = word
            if root_word not in assigned_words:
                return root_word

    for word in words:
        if word not in assigned_words:
            return word

    # If all words are already assigned, assign a unique repeated word with a numbering scheme
    numbering = 1
    while True:
        repeated_word = f"{words[0]}_{numbering}"
        if repeated_word not in assigned_words:
            return repeated_word
        numbering += 1

    # If no unique repeated word can be assigned, return None
    return None

# Assuming df is your DataFrame
assigned_words = set()
df['topic_title'] = df['topics'].apply(lambda x: get_most_repeated_word(x, assigned_words) if isinstance(x, list) else None)

# Update the assigned_words set with the newly assigned repeated words
assigned_words.update(df['topic_title'].dropna())

# Print the DataFrame to verify the changes
print(df)
# Out:
#                                                     body  \
# 0       Maybe Al Gore can drive him there in his Hummer.
# 1      The reason for that is because flood insurance...
# 2       Oh I’ve met quite a few. Depends where you live.
# 3      I’v met a couple. Similar to when convos start...
# 4      Your officials are electeded?\nUk and Scotland...
# ...                                                  ...
# 15720  to address the counter point: the arguments ma...
# 15721                      Right. Who gets a cell phone?
# 15722  It's silly to ask that question when the capit...
# 15723  We're either going to run out of resources or ...
# 15724  Hahahaha that's so good. Wish the conversation...
#
#                                               post_title  \
# 0      To fight climate change, ban private jets, not...
# 1      To fight climate change, ban private jets, not...
# 2      To fight climate change, ban private jets, not...
# 3      To fight climate change, ban private jets, not...
# 4      To fight climate change, ban private jets, not...
# ...                                                  ...
# 15720  What societal changes would you be open to as ...
# 15721  What societal changes would you be open to as ...
# 15722  What societal changes would you be open to as ...
# 15723  What societal changes would you be open to as ...
# 15724  What societal changes would you be open to as ...
#
#                                                   topics repeated_word
# 0      [climate, warming, scientists, scientist, scie...     scientist
# 1      [floods, flooding, flood, hurricane, flooded, ...         flood
# 2      [location, cities, city, texas, where, area, c...      location
# 3      [climate, warming, scientists, scientist, scie...     scientist
# 4      [scotland, scotlands, scottish, funding, taxpa...      scotland
# ...                                                  ...           ...
# 15720  [keynesians, keynesian, economists, keynes, ec...     keynesian
# 15721  [smartphones, phones, cellphone, iphones, ipho...         phone
# 15722  [smartphones, phones, cellphone, iphones, ipho...         phone
# 15723  [recycling, recycled, recycle, recyclables, re...       recycle
# 15724  [lol, hahaha, haha, lmao, hahahaha, hahahahaha...           lol
#
# [15725 rows x 4 columns]

# %%
# Group the DataFrame by 'repeated_word' and apply a lambda function to create a set of unique topics for each repeated word
df_duplicates = df.groupby('topic_title')['topics'].apply(lambda x: set(tuple(topic) for topic in x)).reset_index()

# Calculate the number of unique topics for each repeated word and add it as a new column 'num_unique_topics'
df_duplicates['num_unique_topics'] = df_duplicates['topics'].apply(len)

# Filter out rows where the number of unique topics is greater than 1, and get the list of duplicated repeated words
duplicated_repeated_words = df_duplicates[df_duplicates['num_unique_topics'] > 1]['topic_title'].tolist()

# Print the list of duplicated repeated words
print(duplicated_repeated_words)
# Out:
# []

# %%
# Define a dictionary to store the unique words for each topic
topic_repeated_words = {
    ('2050', '2030s', 'catastrophic', 'decades', '2040s', '2060', '2045', 'famine', 'billion', '2040'): 'catastrophe',
    #add more topics and topic titles
}

def update_repeated_word(row):
    topics = tuple(row['topics'])  # Convert the list to a tuple
    repeated_word = row['topic_title']
    
    # Update the repeated word based on the topic using the dictionary
    if topics in topic_repeated_words:
        repeated_word = topic_repeated_words[topics]
    
    # Return the updated repeated word
    return repeated_word

# Apply the function to update the repeated word column
df['topic_title'] = df.apply(update_repeated_word, axis=1)

# %%
df.to_csv('edge_list.csv', index=False)
